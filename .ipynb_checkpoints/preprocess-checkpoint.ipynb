# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats as sp
import csv

# %%
raw_data_path = 'data/'

prior = pd.read_csv(raw_data_path + 'results.csv')
fifa_dataset = pd.read_csv(raw_data_path + 'CompleteDataset.csv')

qualified_countries = ['Egypt', 'Morocco', 'Nigeria', 'Senegal', 'Tunisia', 'Australia', 'Iran', 'Japan', 'Korea Republic', 'Saudi Arabia', 'Belgium', 'Croatia', 'Denmark', 'England', 'France', 'Germany', 'Iceland', 'Poland', 'Portugal', 'Russia', 'Serbia', 'Spain', 'Sweden', 'Switzerland', 'Costa Rica', 'Mexico', 'Panama', 'Argentina', 'Brazil', 'Colombia', 'Peru', 'Uruguay']

# %%
fifa_dataset.drop(labels = ['Unnamed: 0', 'Age', 'Photo', 'Flag', 'Club', 'Club Logo', 'Wage'], axis = 1, inplace = True)

prior.drop(labels = ['city', 'country', 'tournament'], axis = 1, inplace = True)
prior = prior[prior.date > '1990-01-01']

# %%
# get qualified countries only
fifa_dataset = fifa_dataset[fifa_dataset['Nationality'].isin(qualified_countries)].fillna(0)

prior = prior[(prior['home_team'].isin(qualified_countries) & prior['away_team'].isin(qualified_countries))]

# get remaining potential
fifa_dataset['Remaining Potential'] = fifa_dataset['Potential'] - fifa_dataset['Overall']

# get only one preferred position (first only)
fifa_dataset['Preferred Position'] = fifa_dataset['Preferred Positions'].str.split().str[0]

# %%
squad_352_strict = ['GK', 'LB|LWB', 'CB', 'RB|RWB', 'LM|W$', 'RM|W$', 'CM', 'CM|CAM|CDM', 'CM|CAM|CDM', 'W$|T$', 'W$|T$']
squad_442_strict = ['GK', 'LB|LWB', 'CB', 'CB', 'RB|RWB', 'LM|W$', 'RM|W$', 'CM', 'CM|CAM|CDM', 'W$|T$', 'W$|T$']
squad_433_strict = ['GK', 'LB|LWB', 'CB', 'CB', 'RB|RWB', 'CM|LM|W$', 'CM|RM|W$', 'CM|CAM|CDM', 'W$|T$', 'W$|T$', 'W$|T$']
squad_343_strict = ['GK', 'LB|LWB', 'CB', 'RB|RWB', 'LM|W$', 'RM|W$', 'CM|CAM|CDM', 'CM|CAM|CDM', 'W$|T$', 'W$|T$', 'W$|T$']
squad_532_strict = ['GK', 'LB|LWB', 'CB|LWB|RWB', 'CB|LWB|RWB', 'CB|LWB|RWB', 'RB|RWB', 'M$|W$', 'M$|W$', 'M$|W$', 'W$|T$', 'W$|T$']

squad_352_adj = ['GK', 'B$', 'B$', 'B$', 'M$|W$|T$', 'M$|W$|T$', 'M$|W$|T$', 'M$|W$|T$', 'M$|W$|T$', 'W$|T$|M$', 'W$|T$|M$']
squad_442_adj = ['GK', 'B$', 'B$', 'B$', 'B$', 'M$|W$|T$', 'M$|W$|T$', 'M$|W$|T$', 'M$|W$|T$', 'W$|T$|M$', 'W$|T$|M$']
squad_433_adj = ['GK', 'B$', 'B$', 'B$', 'B$', 'M$|W$|T$', 'M$|W$|T$', 'M$|W$|T$', 'W$|T$|M$', 'W$|T$|M$', 'W$|T$|M$']
squad_343_adj = ['GK', 'B$', 'B$', 'B$', 'M$|W$|T$', 'M$|W$|T$', 'M$|W$|T$', 'M$|W$|T$', 'W$|T$|M$', 'W$|T$|M$', 'W$|T$|M$']
squad_532_adj = ['GK', 'B$', 'B$', 'B$', 'B$', 'B$', 'M$|W$|T$', 'M$|W$|T$', 'M$|W$|T$', 'W$|T$|M$', 'W$|T$|M$']

midfield = ['CDM', 'CM', 'RM', 'LM']
defense = ['GK', 'LB', 'CB', 'RB', 'LWB', 'RWB']
attack = ['LW', 'RW', 'ST', 'CAM']

squad_list_strict = [squad_352_strict, squad_442_strict, squad_433_strict, squad_343_strict, squad_532_strict]
squad_list_adj = [squad_352_adj, squad_442_adj, squad_433_adj, squad_343_adj, squad_532_adj]
squad_name = ['3-5-2', '4-4-2', '4-3-3', '3-4-3', '5-3-2']

# %%
def get_best_squad_n(position, nationality, df, measurement = 'Potential'):
    df_copy = df.copy()
    df_copy = df_copy[df_copy['Nationality'] == nationality]
    store = []
    team = []
    for i in position:
        store.append([df_copy.loc[[df_copy[df_copy['Preferred Position'].str.contains(i)][measurement].idxmax()]]['Preferred Position'].to_string(index = False), df_copy[df_copy['Preferred Position'].str.contains(i)][measurement].max()])
        team.append(df_copy.loc[[df_copy[df_copy['Preferred Position'].str.contains(i)][measurement].idxmax()]]['Name'].to_string(index = False))
        df_copy.drop(df_copy[df_copy['Preferred Position'].str.contains(i)][measurement].idxmax(), inplace = True)
    return np.mean([x[1] for x in store]).round(2), np.array(team), pd.DataFrame(np.array(store).reshape(11,2), columns = ['Position', measurement]).to_string(index = False)

def get_best_formation_all(squad_list, country):
    best_rating = 0
    best_squad, best_formation = [], []
    for i, formation in enumerate(squad_list):
        #curRating, cur_squad = get_best_squad_n(formation, country, fifa_dataset, 'Overall')
        potRating, pot_squad, squad_info = get_best_squad_n(formation, country, fifa_dataset, 'Potential')
        if potRating > best_rating:
            best_rating = potRating
            best_squad = pot_squad
            best_formation = squad_name[i]
    return best_rating, best_squad, best_formation, squad_info
    
def get_team_stats(squad_stats):
    midRating, defRating, attRating  = [], [], []
    for player in squad_stats.split('\n'):
        pos, rating = player.split()[0], player.split()[-1]
        if pos in midfield: midRating.append(float(rating))
        if pos in defense: defRating.append(float(rating))
        if pos in attack: attRating.append(float(rating))
    return np.mean(midRating).round(2), np.mean(defRating).round(2), np.mean(attRating).round(2)

# %%
# create data-set with team information
def make_team_dataframe():
    d = []
    for country in qualified_countries:
            best_rating, best_squad, best_formation, squad_stats = get_best_formation_all(squad_list_adj, country)
            mid_rating, def_rating, att_rating = get_team_stats(squad_stats)
            if best_rating > 84.0: tier = 1
            elif best_rating > 77.0: tier = 2
            else: tier = 3
            d.append({'Country': country, 'Rating': best_rating, 'Squad': best_squad, 'Defence': def_rating, 'Midfield': mid_rating, 'Attack': att_rating, 'Formation': best_formation,'Tier': tier})

    processed_data = pd.DataFrame(d).reindex_axis(['Country', 'Squad', 'Formation', 'Tier', 'Rating', 'Attack', 'Midfield', 'Defence'], axis = 1).set_index('Country')
    processed_data.to_csv('data/WC18_processed.csv', index_label = False)

# %%
d = []
for country in qualified_countries:
        best_rating, best_squad, best_formation, squad_stats = get_best_formation_all(squad_list_adj, country)
        mid_rating, def_rating, att_rating = get_team_stats(squad_stats)
        if best_rating > 84.0: tier = 1
        elif best_rating > 77.0: tier = 2
        else: tier = 3
        d.append({'Country': country, 'Rating': best_rating, 'Squad': best_squad, 'Defence': def_rating, 'Midfield': mid_rating, 'Attack': att_rating, 'Formation': best_formation,'Tier': tier})

processed_data = pd.DataFrame(d).reindex_axis(['Country', 'Squad', 'Formation', 'Tier', 'Rating', 'Attack', 'Midfield', 'Defence'], axis = 1).set_index('Country')
#print processed_data
# Out:
#                                                             Squad Formation  \
# Country
# Egypt           [A. El-Shenawy, A. Hegazy, K. Hafez, O. Gaber,...     3-5-2
# Morocco         [Y. Bounou, M. Benatia, A. Hakimi, Z. Feddal, ...     3-5-2
# Nigeria         [V. Enyeama, C. Awaziem, K. Omeruo, U. Agbo, O...     3-5-2
# Senegal         [A. Gomis, K. Koulibaly, K. Mbodj, K. Mbodj, K...     3-5-2
# Tunisia         [F. Ben Mustapha, A. Abdennour, Y. Benalouane,...     3-5-2
# Australia       [M. Ryan, A. Gersbach, T. Sainsbury, B. Wright...     3-5-2
# Iran            [A. Haghighi, M. Mohammadi, K. Ansarifard, K. ...     3-5-2
# Japan           [K. Nakamura, G. Shoji, N. Ueda, M. Hasebe, Y....     3-5-2
# Korea Republic  [Yoon Bo Sang, Kim Min Jae, An Hyeon Beom, Kim...     3-5-2
# Saudi Arabia    [M. Al Owais, M. Hawsawi, O. Hawsawi, Y. Al Sh...     4-4-2
# Belgium         [T. Courtois, T. Alderweireld, L. Dendoncker, ...     3-5-2
# Croatia         [D. Subašić, T. Jedvaj, D. Lovren, S. Vrsaljko...     3-5-2
# Denmark         [K. Schmeichel, J. Vestergaard, S. Kjær, F. Sø...     3-5-2
# England         [J. Butland, M. Keane, A. Oxlade-Chamberlain, ...     3-5-2
# France          [A. Lafont, R. Varane, A. Laporte, S. Umtiti, ...     3-5-2
# Germany         [M. Neuer, N. Süle, J. Boateng, M. Hummels, J....     4-4-2
# Iceland         [R. Rúnarsson, S. Ingason, H. Hermannsson, D. ...     3-5-2
# Poland          [B. Drągowski, K. Glik, L. Piszczek, J. Bednar...     3-5-2
# Portugal        [A. Lopes, Nélson Semedo, Pepe, Rúben Semedo, ...     3-5-2
# Russia          [S. Kritsyuk, G. Dzhikiya, I. Kutepov, E. Nabi...     3-5-2
# Serbia          [F. Manojlović, M. Nastasić, N. Maksimović, V....     3-5-2
# Spain           [De Gea, Sergio Ramos, Héctor Bellerín, Piqué,...     3-5-2
# Sweden          [P. Dahlberg, V. Lindelöf, L. Augustinsson, A....     3-5-2
# Switzerland     [R. Bürki, R. Rodríguez, N. Elvedi, M. Akanji,...     3-5-2
# Costa Rica      [K. Navas, G. González, K. Waston, F. Calvo, C...     4-4-2
# Mexico          [G. Ochoa, D. Reyes, C. Montes, H. Moreno, J. ...     3-5-2
# Panama          [R. Torres, A. Machado, H. Cummings, F. Escoba...     3-5-2
# Argentina       [G. Rulli, M. Musacchio, E. Mammana, J. Foyth,...     3-5-2
# Brazil          [Ederson, Marquinhos, Thiago Silva, Marcelo, N...     3-5-2
# Colombia        [D. Ospina, D. Sánchez, J. Murillo, J. Lerma, ...     3-5-2
# Peru            [P. Gallese, C. Zambrano, A. Callens, A. Rodrí...     3-5-2
# Uruguay         [F. Muslera, D. Godín, J. Giménez, M. Saracchi...     3-5-2
#
#                 Tier  Rating  Attack  Midfield  Defence
# Country
# Egypt              2   79.00   82.33     83.00    74.17
# Morocco            2   81.55   84.00     82.50    78.83
# Nigeria            2   82.82   84.50     85.33    79.00
# Senegal            1   84.18   87.25     84.00    81.17
# Tunisia            3   74.45   78.00     76.00    72.33
# Australia          2   77.82   77.33     78.50    77.50
# Iran               3   76.55   79.75     79.00    71.67
# Japan              2   79.55   80.50     81.00    77.67
# Korea Republic     2   80.36   82.00     79.00    78.83
# Saudi Arabia       2   77.45   79.33     77.00    76.50
# Belgium            1   88.64   90.33     91.00    86.33
# Croatia            1   85.55   86.00     87.50    83.00
# Denmark            1   84.55   85.50     87.67    81.67
# England            1   87.64   90.00     89.00    85.50
# France             1   90.73   92.33     91.50    89.00
# Germany            1   88.82   88.00     89.67    88.50
# Iceland            3   75.82   75.50     77.67    74.67
# Poland             1   84.64   88.50     85.00    81.67
# Portugal           1   87.73   90.00     89.50    85.33
# Russia             2   81.82   82.00     83.33    80.50
# Serbia             2   83.45   85.50     84.00    82.00
# Spain              1   89.45   90.50     90.00    88.50
# Sweden             2   82.64   84.00     85.00    80.83
# Switzerland        1   84.45   85.67     85.50    83.33
# Costa Rica         3   75.91   80.00     75.75    75.17
# Mexico             2   82.45   85.00     83.75    80.33
# Panama             3   70.91   72.00     71.67    68.17
# Argentina          1   89.00   91.25     90.00    85.67
# Brazil             1   89.09   91.67     88.50    87.50
# Colombia           2   83.64   83.50     89.00    82.67
# Peru               3   76.91   77.50     78.33    74.83
# Uruguay            1   85.45   89.50     84.33    84.50

# %%
#pdata = make_team_dataframe()
#print pdata#.head(10)
# for each team: goals scored, goals allowed, wins, loses, win difference, per year
# for each year: total num goals, goal differential,
#team.append(df_copy.loc[[df_copy[df_copy['Preferred Position'].str.contains(i)][measurement].idxmax()]]['Name'].to_string(index = False))

#print prior.head(5)
pGF = prior[(prior['home_team'] == 'Germany') & (prior['away_team'] == 'France')]['home_score'].to_string(index = False).split('\n')
#sp.mode(np.array(map(int, pGF)))
m, count = sp.mode(map(int, pGF))
print m
#pGF = np.mean(prior[(prior['home_team'] == 'Germany') & (prior['away_team'] == 'France')]['away_score'].to_string(index = False))
#pFG = prior[(prior['home_team'] == 'France') & (prior['away_team'] == 'Germany')]

#[fifa_dataset[fifa_dataset['Preferred Position'].str.contains('RM')]['Potential'].idxmax()]
#fifa_dataset[fifa_dataset['Preferred Position'].str.contains('GK')]
#,'-', prior[(prior['home_team'] == 'Germany') & (prior['away_team'] == 'France')]
#print prior[(prior.home_team == 'Germany') & (prior.away_team == 'France')]#.home_score
#print prior[(prior['home_team'] == 'Germany') & (prior['away_team'] == 'France')]
#for g in prior[(prior['home_team'] == 'Germany') & (prior['away_team'] == 'France')].iterrows():
#    print g#.home_score, '-', g.away_score
#prior[(prior['home_team'] == 'Germany') & (prior['away_team'] == 'France')].home_score
# Out:
# [0]

# %%
for countryA in qualified_countries:
    for countryB in qualified_countries:
        if countryA == countryB: continue
        print #countryA, ' vs ', countryB
        print prior[(prior['home_team'] == countryA) & (prior['away_team'] == countryB)]#.home_score.get_value(), '-', prior[(prior['home_team'] == countryA) & (prior['away_team'] == countryB)].away_score
    


# --------
def single_game(A, B):
    xAB = prior[prior.home_team == A].home_score
# Out:
#              date home_team away_team  home_score  away_score
# 23310  2001-01-28     Egypt   Morocco           0           0
# 27746  2006-01-24     Egypt   Morocco           0           0
# 37951  2017-01-29     Egypt   Morocco           1           0
#
#              date home_team away_team  home_score  away_score
# 31436  2010-01-12     Egypt   Nigeria           3           1
# 33470  2012-04-12     Egypt   Nigeria           3           2
# 37185  2016-03-29     Egypt   Nigeria           1           0
#
#              date home_team away_team  home_score  away_score
# 22268  2000-01-28     Egypt   Senegal           1           0
# 23675  2001-05-06     Egypt   Senegal           1           0
# 24282  2002-01-20     Egypt   Senegal           0           1
# 25647  2003-10-10     Egypt   Senegal           1           0
# 27718  2005-12-29     Egypt   Senegal           4           2
# 27778  2006-02-07     Egypt   Senegal           2           1
# 35957  2014-11-15     Egypt   Senegal           0           1
#
#              date home_team away_team  home_score  away_score
# 22312  2000-02-07     Egypt   Tunisia           0           1
# 24300  2002-01-25     Egypt   Tunisia           1           0
# 27636  2005-11-16     Egypt   Tunisia           1           2
# 34053  2012-10-16     Egypt   Tunisia           0           1
# 35750  2014-09-10     Egypt   Tunisia           0           1
# 37897  2017-01-08     Egypt   Tunisia           1           0
#
#              date home_team  away_team  home_score  away_score
# 32126  2010-11-17     Egypt  Australia           3           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team       away_team  home_score  away_score
# 22762  2000-06-09     Egypt  Korea Republic           0           1
# 23648  2001-04-26     Egypt  Korea Republic           1           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 27002  2005-02-09     Egypt   Belgium           4           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 25030  2003-02-12     Egypt   Denmark           1           4
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 25796  2003-11-18     Egypt    Sweden           1           0
# 28614  2007-02-07     Egypt    Sweden           2           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team  away_team  home_score  away_score
# 29667  2008-03-26     Egypt  Argentina           0           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 28140  2006-08-16     Egypt   Uruguay           0           2
#
#              date home_team away_team  home_score  away_score
# 23868  2001-06-30   Morocco     Egypt           1           0
#
#              date home_team away_team  home_score  away_score
# 35282  2014-01-25   Morocco   Nigeria           3           4
#
#              date home_team away_team  home_score  away_score
# 23382  2001-02-24   Morocco   Senegal           0           0
# 25043  2003-02-12   Morocco   Senegal           1           0
# 29428  2007-11-21   Morocco   Senegal           3           0
# 33499  2012-05-25   Morocco   Senegal           0           1
#
#              date home_team away_team  home_score  away_score
# 23483  2001-03-24   Morocco   Tunisia           2           0
# 26578  2004-09-04   Morocco   Tunisia           1           1
# 28624  2007-02-07   Morocco   Tunisia           1           1
# 33323  2012-01-23   Morocco   Tunisia           1           2
# 34777  2013-07-13   Morocco   Tunisia           0           0
# 36460  2015-06-15   Morocco   Tunisia           1           1
# 38070  2017-03-28   Morocco   Tunisia           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team       away_team  home_score  away_score
# 23337  2001-02-08   Morocco  Korea Republic           1           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 22751  2000-06-06   Morocco    France           1           5
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team    away_team  home_score  away_score
# 26003  2004-02-18   Morocco  Switzerland           2           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team  away_team  home_score  away_score
# 26147  2004-04-28   Morocco  Argentina           0           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 36232  2015-03-28   Morocco   Uruguay           0           1
#
#              date home_team away_team  home_score  away_score
# 24894  2002-11-25   Nigeria     Egypt           1           1
# 37135  2016-03-25   Nigeria     Egypt           1           1
#
#              date home_team away_team  home_score  away_score
# 22294  2000-02-03   Nigeria   Morocco           2           0
# 25927  2004-01-27   Nigeria   Morocco           0           1
#
#              date home_team away_team  home_score  away_score
# 22313  2000-02-07   Nigeria   Senegal           2           1
# 24329  2002-02-07   Nigeria   Senegal           1           2
# 27770  2006-01-31   Nigeria   Senegal           2           1
# 37986  2017-03-23   Nigeria   Senegal           1           1
#
#              date home_team away_team  home_score  away_score
# 22251  2000-01-23   Nigeria   Tunisia           4           2
# 27776  2006-02-04   Nigeria   Tunisia           1           1
# 31119  2009-09-06   Nigeria   Tunisia           2           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team       away_team  home_score  away_score
# 31709  2010-06-22   Nigeria  Korea Republic           2           2
#
#              date home_team     away_team  home_score  away_score
# 31598  2010-05-25   Nigeria  Saudi Arabia           0           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 24570  2002-06-12   Nigeria   England           0           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 34745  2013-06-23   Nigeria     Spain           0           3
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team  away_team  home_score  away_score
# 32528  2011-06-01   Nigeria  Argentina           4           1
# 35575  2014-06-25   Nigeria  Argentina           2           3
#
#              date home_team away_team  home_score  away_score
# 25361  2003-06-11   Nigeria    Brazil           0           3
#
#              date home_team away_team  home_score  away_score
# 31631  2010-05-30   Nigeria  Colombia           1           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 34740  2013-06-20   Nigeria   Uruguay           1           2
#
#              date home_team away_team  home_score  away_score
# 22887  2000-07-09   Senegal     Egypt           0           0
# 35676  2014-09-05   Senegal     Egypt           2           0
#
#              date home_team away_team  home_score  away_score
# 23900  2001-07-14   Senegal   Morocco           1           0
# 32783  2011-08-10   Senegal   Morocco           0           2
#
#              date home_team away_team  home_score  away_score
# 24798  2002-10-12   Senegal   Nigeria           2           2
# 27782  2006-02-09   Senegal   Nigeria           0           1
#
#              date home_team away_team  home_score  away_score
# 24319  2002-01-31   Senegal   Tunisia           0           0
# 35797  2014-10-10   Senegal   Tunisia           0           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 24569  2002-06-11   Senegal   Uruguay           3           3
#
#              date home_team away_team  home_score  away_score
# 24889  2002-11-20   Tunisia     Egypt           0           0
# 36034  2014-11-19   Tunisia     Egypt           2           1
#
#              date home_team away_team  home_score  away_score
# 22274  2000-01-29   Tunisia   Morocco           0           0
# 23268  2001-01-13   Tunisia   Morocco           0           1
# 25681  2003-10-11   Tunisia   Morocco           0           0
# 25974  2004-02-14   Tunisia   Morocco           2           1
# 27549  2005-10-08   Tunisia   Morocco           2           2
# 36844  2015-10-25   Tunisia   Morocco           2           3
#
#              date home_team away_team  home_score  away_score
# 25966  2004-02-11   Tunisia   Nigeria           1           1
# 30949  2009-06-20   Tunisia   Nigeria           0           0
# 37039  2016-01-22   Tunisia   Nigeria           1           1
#
#              date home_team away_team  home_score  away_score
# 22775  2000-06-11   Tunisia   Senegal           4           1
# 25262  2003-04-30   Tunisia   Senegal           1           0
# 25959  2004-02-07   Tunisia   Senegal           1           0
# 29521  2008-01-23   Tunisia   Senegal           2           2
# 35892  2014-10-15   Tunisia   Senegal           1           0
# 37917  2017-01-15   Tunisia   Senegal           0           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 24581  2002-06-14   Tunisia     Japan           0           2
# 25643  2003-10-08   Tunisia     Japan           0           1
#
#              date home_team       away_team  home_score  away_score
# 24384  2002-03-13   Tunisia  Korea Republic           0           0
#
#              date home_team     away_team  home_score  away_score
# 28039  2006-06-14   Tunisia  Saudi Arabia           2           2
# 31249  2009-10-14   Tunisia  Saudi Arabia           0           1
#
#              date home_team away_team  home_score  away_score
# 24565  2002-06-10   Tunisia   Belgium           1           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 24687  2002-08-21   Tunisia    France           1           1
# 31633  2010-05-30   Tunisia    France           1           1
#
#              date home_team away_team  home_score  away_score
# 27308  2005-06-18   Tunisia   Germany           0           3
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 27859  2006-03-01   Tunisia    Serbia           0           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 25051  2003-02-12   Tunisia    Sweden           1           0
#
#              date home_team    away_team  home_score  away_score
# 23216  2000-11-15   Tunisia  Switzerland           1           1
# 34160  2012-11-14   Tunisia  Switzerland           1           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 33438  2012-02-29   Tunisia      Peru           1           1
#
#              date home_team away_team  home_score  away_score
# 28000  2006-06-02   Tunisia   Uruguay           0           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date  home_team away_team  home_score  away_score
# 29362  2007-11-17  Australia   Nigeria           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date  home_team away_team  home_score  away_score
# 27319  2005-06-21  Australia   Tunisia           0           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date  home_team away_team  home_score  away_score
# 28031  2006-06-12  Australia     Japan           3           1
# 30933  2009-06-17  Australia     Japan           2           1
# 32318  2011-01-29  Australia     Japan           0           1
# 33671  2012-06-12  Australia     Japan           1           1
# 37714  2016-10-11  Australia     Japan           1           1
#
#              date  home_team       away_team  home_score  away_score
# 23067  2000-10-07  Australia  Korea Republic           2           4
# 32277  2011-01-14  Australia  Korea Republic           1           1
# 36103  2015-01-17  Australia  Korea Republic           0           1
#
#              date  home_team     away_team  home_score  away_score
# 33378  2012-02-29  Australia  Saudi Arabia           4           2
# 35716  2014-09-08  Australia  Saudi Arabia           3           2
# 38148  2017-06-08  Australia  Saudi Arabia           3           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date  home_team away_team  home_score  away_score
# 28596  2007-02-06  Australia   Denmark           1           3
# 31635  2010-06-01  Australia   Denmark           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date  home_team away_team  home_score  away_score
# 23749  2001-06-01  Australia    France           1           0
# 24168  2001-11-11  Australia    France           1           1
#
#              date  home_team away_team  home_score  away_score
# 38247  2017-06-19  Australia   Germany           2           3
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date  home_team away_team  home_score  away_score
# 31710  2010-06-23  Australia    Serbia           2           1
# 32584  2011-06-07  Australia    Serbia           0           0
#
#              date  home_team away_team  home_score  away_score
# 35563  2014-06-23  Australia     Spain           0           3
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date  home_team   away_team  home_score  away_score
# 35162  2013-11-19  Australia  Costa Rica           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date  home_team  away_team  home_score  away_score
# 27299  2005-06-18  Australia  Argentina           2           4
# 29189  2007-09-11  Australia  Argentina           0           1
#
#              date  home_team away_team  home_score  away_score
# 23829  2001-06-09  Australia    Brazil           1           0
# 38214  2017-06-13  Australia    Brazil           0           4
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date  home_team away_team  home_score  away_score
# 24193  2001-11-20  Australia   Uruguay           1           0
# 27632  2005-11-16  Australia   Uruguay           1           0
# 28807  2007-06-02  Australia   Uruguay           1           2
#
#              date home_team away_team  home_score  away_score
# 22756  2000-06-07      Iran     Egypt           1           1
#
#              date home_team away_team  home_score  away_score
# 24761  2002-09-17      Iran   Morocco           1           1
#
#              date home_team away_team  home_score  away_score
# 35541  2014-06-16      Iran   Nigeria           0           0
#
#              date home_team away_team  home_score  away_score
# 30786  2009-04-01      Iran   Senegal           1           1
#
#              date home_team away_team  home_score  away_score
# 33783  2012-08-15      Iran   Tunisia           2           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 27081  2005-03-25      Iran     Japan           2           1
# 36798  2015-10-13      Iran     Japan           1           1
#
#              date home_team       away_team  home_score  away_score
# 23156  2000-10-23      Iran  Korea Republic           1           2
# 23615  2001-04-24      Iran  Korea Republic           0           1
# 28443  2006-11-15      Iran  Korea Republic           2           0
# 29040  2007-07-22      Iran  Korea Republic           0           0
# 30668  2009-02-11      Iran  Korea Republic           1           1
# 32310  2011-01-22      Iran  Korea Republic           0           1
# 34060  2012-10-16      Iran  Korea Republic           1           0
# 36003  2014-11-18      Iran  Korea Republic           1           0
# 37722  2016-10-11      Iran  Korea Republic           1           0
#
#              date home_team     away_team  home_score  away_score
# 23998  2001-08-24      Iran  Saudi Arabia           2           0
# 30731  2009-03-28      Iran  Saudi Arabia           1           2
# 34238  2012-12-09      Iran  Saudi Arabia           0           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 26684  2004-10-09      Iran   Germany           0           2
#
#              date home_team away_team  home_score  away_score
# 31285  2009-11-10      Iran   Iceland           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 32346  2011-02-09      Iran    Russia           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team   away_team  home_score  away_score
# 27834  2006-03-01      Iran  Costa Rica           3           2
# 29547  2008-01-30      Iran  Costa Rica           0           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 26924  2004-12-18      Iran    Panama           1           0
# 38595  2017-11-09      Iran    Panama           2           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 31956  2010-10-07      Iran    Brazil           0           3
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 29304  2007-10-17     Japan     Egypt           4           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 24116  2001-10-07     Japan   Nigeria           2           2
# 25517  2003-08-20     Japan   Nigeria           3           0
#
#              date home_team away_team  home_score  away_score
# 24084  2001-10-04     Japan   Senegal           0           2
# 25588  2003-09-10     Japan   Senegal           0           1
#
#              date home_team away_team  home_score  away_score
# 36209  2015-03-27     Japan   Tunisia           2           0
#
#              date home_team  away_team  home_score  away_score
# 23825  2001-06-07     Japan  Australia           1           0
# 23979  2001-08-15     Japan  Australia           3           0
# 29039  2007-07-21     Japan  Australia           1           1
# 30671  2009-02-11     Japan  Australia           0           0
# 34620  2013-06-04     Japan  Australia           1           1
# 34803  2013-07-25     Japan  Australia           3           2
# 36006  2014-11-18     Japan  Australia           2           1
# 38357  2017-08-31     Japan  Australia           2           0
#
#              date home_team away_team  home_score  away_score
# 26491  2004-07-28     Japan      Iran           0           0
# 27394  2005-08-17     Japan      Iran           2           1
#
#              date home_team       away_team  home_score  away_score
# 23247  2000-12-20     Japan  Korea Republic           1           1
# 25287  2003-05-31     Japan  Korea Republic           0           1
# 25855  2003-12-10     Japan  Korea Republic           0           0
# 29625  2008-02-23     Japan  Korea Republic           1           1
# 31484  2010-02-14     Japan  Korea Republic           1           3
# 31590  2010-05-24     Japan  Korea Republic           0           2
# 32315  2011-01-25     Japan  Korea Republic           2           2
# 32766  2011-08-10     Japan  Korea Republic           3           0
# 36546  2015-08-05     Japan  Korea Republic           1           1
# 38735  2017-12-16     Japan  Korea Republic           1           4
#
#              date home_team     away_team  home_score  away_score
# 23169  2000-10-29     Japan  Saudi Arabia           1           0
# 28449  2006-11-15     Japan  Saudi Arabia           3           1
# 29044  2007-07-25     Japan  Saudi Arabia           2           3
# 37850  2016-11-15     Japan  Saudi Arabia           2           1
#
#              date home_team away_team  home_score  away_score
# 24542  2002-06-04     Japan   Belgium           2           2
# 30845  2009-05-31     Japan   Belgium           4           0
#
#              date home_team away_team  home_score  away_score
# 28051  2006-06-18     Japan   Croatia           0           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 31629  2010-05-30     Japan   England           1           2
#
#              date home_team away_team  home_score  away_score
# 23832  2001-06-10     Japan    France           0           1
#
#              date home_team away_team  home_score  away_score
# 26917  2004-12-16     Japan   Germany           0           3
#
#              date home_team away_team  home_score  away_score
# 33365  2012-02-24     Japan   Iceland           3           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 24560  2002-06-09     Japan    Russia           1           0
#
#              date home_team away_team  home_score  away_score
# 23885  2001-07-04     Japan    Serbia           1           0
# 26452  2004-07-13     Japan    Serbia           1           0
# 31563  2010-04-07     Japan    Serbia           0           3
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 24523  2002-05-25     Japan    Sweden           1           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team   away_team  home_score  away_score
# 24452  2002-04-17     Japan  Costa Rica           1           1
#
#              date home_team away_team  home_score  away_score
# 22303  2000-02-05     Japan    Mexico           0           1
# 27297  2005-06-16     Japan    Mexico           1           2
# 34743  2013-06-22     Japan    Mexico           1           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team  away_team  home_score  away_score
# 24877  2002-11-20     Japan  Argentina           0           2
# 25337  2003-06-08     Japan  Argentina           1           4
# 26523  2004-08-18     Japan  Argentina           1           2
# 31972  2010-10-08     Japan  Argentina           1           0
#
#              date home_team away_team  home_score  away_score
# 27322  2005-06-22     Japan    Brazil           2           2
# 28066  2006-06-22     Japan    Brazil           1           4
# 34065  2012-10-16     Japan    Brazil           0           4
# 35869  2014-10-14     Japan    Brazil           0           4
# 38616  2017-11-10     Japan    Brazil           1           3
#
#              date home_team away_team  home_score  away_score
# 25395  2003-06-22     Japan  Colombia           0           1
# 28860  2007-06-05     Japan  Colombia           0           0
# 35570  2014-06-24     Japan  Colombia           1           4
#
#              date home_team away_team  home_score  away_score
# 27177  2005-05-22     Japan      Peru           0           1
# 28690  2007-03-24     Japan      Peru           2           0
# 32526  2011-06-01     Japan      Peru           0           0
#
#              date home_team away_team  home_score  away_score
# 25142  2003-03-28     Japan   Uruguay           2           2
# 30135  2008-08-20     Japan   Uruguay           1           3
# 34842  2013-08-14     Japan   Uruguay           2           4
# 35672  2014-09-05     Japan   Uruguay           0           2
#
#              date       home_team away_team  home_score  away_score
# 26984  2005-02-04  Korea Republic     Egypt           0           1
#
#              date       home_team away_team  home_score  away_score
# 38581  2017-10-10  Korea Republic   Morocco           1           3
#
#              date       home_team away_team  home_score  away_score
# 24067  2001-09-13  Korea Republic   Nigeria           2           2
# 24074  2001-09-16  Korea Republic   Nigeria           2           1
# 31770  2010-08-11  Korea Republic   Nigeria           2           1
#
#              date       home_team away_team  home_score  away_score
# 24155  2001-11-08  Korea Republic   Senegal           0           1
# 27938  2006-05-23  Korea Republic   Senegal           1           1
# 31235  2009-10-14  Korea Republic   Senegal           2           0
#
#              date       home_team away_team  home_score  away_score
# 35433  2014-05-28  Korea Republic   Tunisia           0           1
#
#              date       home_team  away_team  home_score  away_score
# 23792  2001-06-03  Korea Republic  Australia           1           0
# 31096  2009-09-05  Korea Republic  Australia           3           1
# 34135  2012-11-14  Korea Republic  Australia           1           2
# 34791  2013-07-20  Korea Republic  Australia           0           0
# 36150  2015-01-31  Korea Republic  Australia           1           2
#
#              date       home_team away_team  home_score  away_score
# 26496  2004-07-31  Korea Republic      Iran           3           4
# 27579  2005-10-12  Korea Republic      Iran           2           0
# 28199  2006-09-02  Korea Republic      Iran           1           1
# 30935  2009-06-17  Korea Republic      Iran           1           1
# 31886  2010-09-07  Korea Republic      Iran           0           1
# 34735  2013-06-18  Korea Republic      Iran           0           1
# 38355  2017-08-31  Korea Republic      Iran           0           0
#
#              date       home_team away_team  home_score  away_score
# 22620  2000-04-26  Korea Republic     Japan           1           0
# 25221  2003-04-16  Korea Republic     Japan           0           1
# 27365  2005-08-07  Korea Republic     Japan           0           1
# 29047  2007-07-28  Korea Republic     Japan           0           0
# 32045  2010-10-12  Korea Republic     Japan           0           0
# 34812  2013-07-28  Korea Republic     Japan           1           2
#
#              date       home_team     away_team  home_score  away_score
# 23164  2000-10-26  Korea Republic  Saudi Arabia           1           2
# 27397  2005-08-17  Korea Republic  Saudi Arabia           0           1
# 29014  2007-07-11  Korea Republic  Saudi Arabia           1           1
# 30918  2009-06-10  Korea Republic  Saudi Arabia           0           0
# 36072  2015-01-04  Korea Republic  Saudi Arabia           2           0
#
#              date       home_team away_team  home_score  away_score
# 35577  2014-06-26  Korea Republic   Belgium           0           1
#
#              date       home_team away_team  home_score  away_score
# 24164  2001-11-10  Korea Republic   Croatia           2           0
# 24173  2001-11-13  Korea Republic   Croatia           1           1
# 27764  2006-01-29  Korea Republic   Croatia           2           0
# 34986  2013-09-10  Korea Republic   Croatia           1           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#              date       home_team away_team  home_score  away_score
# 24515  2002-05-21  Korea Republic   England           1           1
#
#              date       home_team away_team  home_score  away_score
# 24528  2002-05-26  Korea Republic    France           2           3
#
#              date       home_team away_team  home_score  away_score
# 26929  2004-12-19  Korea Republic   Germany           3           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date       home_team away_team  home_score  away_score
# 24543  2002-06-04  Korea Republic    Poland           2           0
# 33013  2011-10-07  Korea Republic    Poland           2           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date       home_team away_team  home_score  away_score
# 22699  2000-05-28  Korea Republic    Serbia           0           0
# 22705  2000-05-30  Korea Republic    Serbia           0           0
# 27641  2005-11-16  Korea Republic    Serbia           2           0
# 31349  2009-11-18  Korea Republic    Serbia           0           1
# 32538  2011-06-03  Korea Republic    Serbia           2           1
# 38669  2017-11-14  Korea Republic    Serbia           1           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date       home_team away_team  home_score  away_score
# 27613  2005-11-12  Korea Republic    Sweden           2           2
#
#              date       home_team    away_team  home_score  away_score
# 35131  2013-11-15  Korea Republic  Switzerland           2           1
#
#              date       home_team   away_team  home_score  away_score
# 22362  2000-02-17  Korea Republic  Costa Rica           2           2
# 24467  2002-04-21  Korea Republic  Costa Rica           2           0
# 35870  2014-10-14  Korea Republic  Costa Rica           1           3
#
#              date       home_team away_team  home_score  away_score
# 23752  2001-06-01  Korea Republic    Mexico           2           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date       home_team  away_team  home_score  away_score
# 25358  2003-06-11  Korea Republic  Argentina           0           1
#
#              date       home_team away_team  home_score  away_score
# 24878  2002-11-20  Korea Republic    Brazil           2           3
# 35052  2013-10-12  Korea Republic    Brazil           0           2
#
#              date       home_team away_team  home_score  away_score
# 25161  2003-03-29  Korea Republic  Colombia           0           0
# 38609  2017-11-10  Korea Republic  Colombia           2           1
#
#              date       home_team away_team  home_score  away_score
# 34844  2013-08-14  Korea Republic      Peru           0           0
#
#              date       home_team away_team  home_score  away_score
# 25338  2003-06-08  Korea Republic   Uruguay           0           2
# 28692  2007-03-24  Korea Republic   Uruguay           0           2
# 35719  2014-09-08  Korea Republic   Uruguay           0           1
#
#              date     home_team away_team  home_score  away_score
# 27072  2005-03-14  Saudi Arabia     Egypt           0           1
#
#              date     home_team away_team  home_score  away_score
# 33711  2012-06-18  Saudi Arabia   Morocco           4           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date     home_team away_team  home_score  away_score
# 24487  2002-05-14  Saudi Arabia   Senegal           3           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date     home_team  away_team  home_score  away_score
# 32956  2011-09-06  Saudi Arabia  Australia           1           3
# 37645  2016-10-06  Saudi Arabia  Australia           2           2
#
#              date     home_team away_team  home_score  away_score
# 24082  2001-09-28  Saudi Arabia      Iran           2           2
# 30222  2008-09-06  Saudi Arabia      Iran           1           1
#
#              date     home_team away_team  home_score  away_score
# 23140  2000-10-14  Saudi Arabia     Japan           1           4
# 28227  2006-09-03  Saudi Arabia     Japan           1           0
# 32295  2011-01-17  Saudi Arabia     Japan           0           5
# 38441  2017-09-05  Saudi Arabia     Japan           1           0
#
#              date     home_team       away_team  home_score  away_score
# 27084  2005-03-25  Saudi Arabia  Korea Republic           2           0
# 30495  2008-11-19  Saudi Arabia  Korea Republic           0           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date     home_team away_team  home_score  away_score
# 24362  2002-02-13  Saudi Arabia   Denmark           0           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date     home_team away_team  home_score  away_score
# 24256  2002-01-10  Saudi Arabia   Iceland           1           0
#
#              date     home_team away_team  home_score  away_score
# 27873  2006-03-28  Saudi Arabia    Poland           1           2
#
#              date     home_team away_team  home_score  away_score
# 27854  2006-03-01  Saudi Arabia  Portugal           0           3
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date     home_team away_team  home_score  away_score
# 28067  2006-06-23  Saudi Arabia     Spain           0           1
#
#              date     home_team away_team  home_score  away_score
# 27732  2006-01-18  Saudi Arabia    Sweden           1           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date     home_team  away_team  home_score  away_score
# 34154  2012-11-14  Saudi Arabia  Argentina           0           0
#
#              date     home_team away_team  home_score  away_score
# 24327  2002-02-06  Saudi Arabia    Brazil           0           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date     home_team away_team  home_score  away_score
# 24425  2002-03-27  Saudi Arabia   Uruguay           3           2
# 35796  2014-10-10  Saudi Arabia   Uruguay           1           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 29658  2008-03-26   Belgium   Morocco           1           4
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 35516  2014-06-07   Belgium   Tunisia           1           0
#
#              date home_team  away_team  home_score  away_score
# 35660  2014-09-04   Belgium  Australia           2           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 35165  2013-11-19   Belgium     Japan           2           3
# 38680  2017-11-14   Belgium     Japan           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team     away_team  home_score  away_score
# 27922  2006-05-11   Belgium  Saudi Arabia           2           1
#
#              date home_team away_team  home_score  away_score
# 22991  2000-09-02   Belgium   Croatia           0           0
# 25579  2003-09-10   Belgium   Croatia           2           1
# 31512  2010-03-03   Belgium   Croatia           0           1
# 33896  2012-09-11   Belgium   Croatia           1           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 25980  2004-02-18   Belgium    France           0           2
# 34826  2013-08-14   Belgium    France           0           0
#
#              date home_team away_team  home_score  away_score
# 31811  2010-09-03   Belgium   Germany           0           1
#
#              date home_team away_team  home_score  away_score
# 35918  2014-11-12   Belgium   Iceland           3           1
#
#              date home_team away_team  home_score  away_score
# 25234  2003-04-30   Belgium    Poland           3           1
# 28429  2006-11-15   Belgium    Poland           0           1
#
#              date home_team away_team  home_score  away_score
# 22379  2000-02-23   Belgium  Portugal           1           1
# 28811  2007-06-02   Belgium  Portugal           1           2
#
#              date home_team away_team  home_score  away_score
# 24578  2002-06-14   Belgium    Russia           3           2
# 35559  2014-06-22   Belgium    Russia           1           0
#
#              date home_team away_team  home_score  away_score
# 26795  2004-11-17   Belgium    Serbia           0           2
# 29067  2007-08-22   Belgium    Serbia           3           2
# 34639  2013-06-07   Belgium    Serbia           2           1
#
#              date home_team away_team  home_score  away_score
# 27512  2005-10-08   Belgium     Spain           0           2
# 30382  2008-10-15   Belgium     Spain           1           2
# 37528  2016-09-01   Belgium     Spain           0           2
#
#              date home_team away_team  home_score  away_score
# 22764  2000-06-10   Belgium    Sweden           2           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team   away_team  home_score  away_score
# 24525  2002-05-26   Belgium  Costa Rica           1           0
#
#              date home_team away_team  home_score  away_score
# ...
# 33637  2012-06-09    Brazil  Argentina           3           4
# 33949  2012-09-19    Brazil  Argentina           2           1
#
#              date home_team away_team  home_score  away_score
# 23196  2000-11-15    Brazil  Colombia           1           0
# 26720  2004-10-13    Brazil  Colombia           0           0
# 30384  2008-10-15    Brazil  Colombia           0           0
# 34115  2012-11-14    Brazil  Colombia           1           1
# 35590  2014-07-04    Brazil  Colombia           2           1
# 36483  2015-06-17    Brazil  Colombia           0           1
# 37593  2016-09-06    Brazil  Colombia           2           1
# 37947  2017-01-26    Brazil  Colombia           1           0
#
#              date home_team away_team  home_score  away_score
# 23620  2001-04-25    Brazil      Peru           1           1
# 23904  2001-07-15    Brazil      Peru           2           0
# 27121  2005-03-27    Brazil      Peru           1           0
# 36435  2015-06-14    Brazil      Peru           2           1
# 37412  2016-06-12    Brazil      Peru           0           1
#
#              date home_team away_team  home_score  away_score
# 22841  2000-06-28    Brazil   Uruguay           1           1
# 25802  2003-11-19    Brazil   Uruguay           3           3
# 29413  2007-11-21    Brazil   Uruguay           2           1
# 34748  2013-06-26    Brazil   Uruguay           2           1
# 37121  2016-03-25    Brazil   Uruguay           2           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 28012  2006-06-04  Colombia   Morocco           2           0
#
#              date home_team away_team  home_score  away_score
# 30469  2008-11-19  Colombia   Nigeria           1           0
#
#              date home_team away_team  home_score  away_score
# 32633  2011-06-25  Colombia   Senegal           2           0
# 35459  2014-05-31  Colombia   Senegal           2           2
#
#              date home_team away_team  home_score  away_score
# 35309  2014-03-05  Colombia   Tunisia           1           1
#
#              date home_team  away_team  home_score  away_score
# 23401  2001-02-28  Colombia  Australia           3           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team       away_team  home_score  away_score
# 26954  2005-01-15  Colombia  Korea Republic           2           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 27196  2005-05-31  Colombia   England           2           3
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 34829  2013-08-14  Colombia    Serbia           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team    away_team  home_score  away_score
# 28714  2007-03-25  Colombia  Switzerland           3           1
#
#              date home_team   away_team  home_score  away_score
# 26458  2004-07-17  Colombia  Costa Rica           2           0
# 32649  2011-07-02  Colombia  Costa Rica           1           0
# 36345  2015-06-06  Colombia  Costa Rica           1           0
# 37404  2016-06-11  Colombia  Costa Rica           2           3
#
#              date home_team away_team  home_score  away_score
# 23939  2001-07-29  Colombia    Mexico           1           0
# 32629  2011-06-22  Colombia    Mexico           0           0
#
#              date home_team away_team  home_score  away_score
# 27331  2005-07-06  Colombia    Panama           0           1
# 27353  2005-07-21  Colombia    Panama           2           3
#
#              date home_team  away_team  home_score  away_score
# 22848  2000-06-29  Colombia  Argentina           1           3
# 25803  2003-11-19  Colombia  Argentina           1           1
# 29404  2007-11-20  Colombia  Argentina           2           1
# 33186  2011-11-15  Colombia  Argentina           1           2
# 36936  2015-11-17  Colombia  Argentina           0           1
#
#              date home_team away_team  home_score  away_score
# 22468  2000-03-28  Colombia    Brazil           0           0
# 25481  2003-07-19  Colombia    Brazil           0           2
# 25571  2003-09-07  Colombia    Brazil           1           2
# 29274  2007-10-14  Colombia    Brazil           0           0
# 38431  2017-09-05  Colombia    Brazil           1           1
#
#              date home_team away_team  home_score  away_score
# 22380  2000-02-23  Colombia      Peru           2           1
# 23928  2001-07-23  Colombia      Peru           3           0
# 23990  2001-08-16  Colombia      Peru           0           1
# 27215  2005-06-04  Colombia      Peru           5           0
# 30908  2009-06-10  Colombia      Peru           1           0
# 32122  2010-11-17  Colombia      Peru           1           1
# 32697  2011-07-16  Colombia      Peru           0           2
# 34686  2013-06-11  Colombia      Peru           2           0
# 36494  2015-06-21  Colombia      Peru           0           0
# 36702  2015-10-08  Colombia      Peru           2           0
#
#              date home_team away_team  home_score  away_score
# 22945  2000-08-15  Colombia   Uruguay           1           0
# 26296  2004-06-06  Colombia   Uruguay           5           0
# 26480  2004-07-24  Colombia   Uruguay           1           2
# 28612  2007-02-07  Colombia   Uruguay           1           3
# 30194  2008-09-06  Colombia   Uruguay           0           1
# 33837  2012-09-07  Colombia   Uruguay           4           0
# 35581  2014-06-28  Colombia   Uruguay           2           0
# 37717  2016-10-11  Colombia   Uruguay           2           2
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 33493  2012-05-23      Peru   Nigeria           1           0
#
#              date home_team away_team  home_score  away_score
# 32638  2011-06-28      Peru   Senegal           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team   away_team  home_score  away_score
# 29686  2008-03-26      Peru  Costa Rica           3           1
# 31982  2010-10-08      Peru  Costa Rica           2           0
#
#              date home_team away_team  home_score  away_score
# 23916  2001-07-18      Peru    Mexico           1           0
# 32673  2011-07-08      Peru    Mexico           1           0
#
#              date home_team away_team  home_score  away_score
# 28162  2006-08-16      Peru    Panama           0           2
# 32324  2011-02-08      Peru    Panama           1           0
#
#              date home_team  away_team  home_score  away_score
# 23031  2000-09-03      Peru  Argentina           1           2
# 26459  2004-07-17      Peru  Argentina           0           1
# 26580  2004-09-04      Peru  Argentina           1           3
# 30272  2008-09-10      Peru  Argentina           1           1
# 33926  2012-09-11      Peru  Argentina           1           1
#
#              date home_team away_team  home_score  away_score
# 22747  2000-06-04      Peru    Brazil           0           1
# 25788  2003-11-16      Peru    Brazil           1           1
# 29394  2007-11-18      Peru    Brazil           1           1
# 37861  2016-11-15      Peru    Brazil           0           2
#
#              date home_team away_team  home_score  away_score
# 22912  2000-07-19      Peru  Colombia           0           1
# 26095  2004-03-31      Peru  Colombia           0           2
# 26449  2004-07-12      Peru  Colombia           2           2
# 29162  2007-09-08      Peru  Colombia           2           2
# 29954  2008-06-14      Peru  Colombia           1           1
# 33595  2012-06-03      Peru  Colombia           0           1
# 37445  2016-06-17      Peru  Colombia           0           0
# 38555  2017-10-10      Peru  Colombia           1           1
#
#              date home_team away_team  home_score  away_score
# 24032  2001-09-04      Peru   Uruguay           0           2
# 25488  2003-07-24      Peru   Uruguay           3           4
# 27252  2005-06-07      Peru   Uruguay           0           0
# 31102  2009-09-05      Peru   Uruguay           1           0
# 32707  2011-07-19      Peru   Uruguay           0           2
# 34927  2013-09-06      Peru   Uruguay           1           2
# 38076  2017-03-28      Peru   Uruguay           2           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team  away_team  home_score  away_score
# 24196  2001-11-25   Uruguay  Australia           3           0
# 27625  2005-11-12   Uruguay  Australia           1           0
#
#              date home_team away_team  home_score  away_score
# 25014  2003-02-04   Uruguay      Iran           1           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team       away_team  home_score  away_score
# 24365  2002-02-13   Uruguay  Korea Republic           2           1
# 31723  2010-06-26   Uruguay  Korea Republic           2           1
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team away_team  home_score  away_score
# 24533  2002-06-01   Uruguay   Denmark           1           2
#
#              date home_team away_team  home_score  away_score
# 35551  2014-06-19   Uruguay   England           2           1
#
#              date home_team away_team  home_score  away_score
# 31669  2010-06-11   Uruguay    France           0           0
# 34631  2013-06-05   Uruguay    France           1           0
#
#              date home_team away_team  home_score  away_score
# 31742  2010-07-10   Uruguay   Germany           2           3
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team   away_team  home_score  away_score
# 23912  2001-07-16   Uruguay  Costa Rica           1           1
# 23926  2001-07-22   Uruguay  Costa Rica           2           1
# 31360  2009-11-18   Uruguay  Costa Rica           1           1
# 35535  2014-06-14   Uruguay  Costa Rica           1           3
# 35929  2014-11-13   Uruguay  Costa Rica           3           3
#
#              date home_team away_team  home_score  away_score
# 32687  2011-07-12   Uruguay    Mexico           1           0
#
# Empty DataFrame
# Columns: [date, home_team, away_team, home_score, away_score]
# Index: []
#
#              date home_team  away_team  home_score  away_score
# 24191  2001-11-14   Uruguay  Argentina           1           1
# 27594  2005-10-12   Uruguay  Argentina           1           0
# 31252  2009-10-14   Uruguay  Argentina           0           1
# 35104  2013-10-15   Uruguay  Argentina           3           2
# 38352  2017-08-31   Uruguay  Argentina           0           0
#
#              date home_team away_team  home_score  away_score
# 23881  2001-07-01   Uruguay    Brazil           1           0
# 26474  2004-07-21   Uruguay    Brazil           1           1
# 27164  2005-03-30   Uruguay    Brazil           1           1
# 29012  2007-07-10   Uruguay    Brazil           2           2
# 30893  2009-06-06   Uruguay    Brazil           0           4
#
#              date home_team away_team  home_score  away_score
# 24120  2001-10-07   Uruguay  Colombia           1           1
# 27470  2005-09-04   Uruguay  Colombia           3           2
# 29608  2008-02-06   Uruguay  Colombia           2           2
# 35001  2013-09-10   Uruguay  Colombia           2           0
#
#              date home_team away_team  home_score  away_score
# 22923  2000-07-26   Uruguay      Peru           0           0
# 25493  2003-07-30   Uruguay      Peru           1           0
# 26253  2004-06-01   Uruguay      Peru           1           3
# 28968  2007-06-26   Uruguay      Peru           0           3
# 29996  2008-06-17   Uruguay      Peru           6           0
# 32663  2011-07-04   Uruguay      Peru           1           1
# 33667  2012-06-10   Uruguay      Peru           4           2
# 37233  2016-03-29   Uruguay      Peru           1           0

# %%
processed_data
# Out:
#                                                             Squad Formation  \
# Country
# Egypt           [A. El-Shenawy, A. Hegazy, K. Hafez, O. Gaber,...     3-5-2
# Morocco         [Y. Bounou, M. Benatia, A. Hakimi, Z. Feddal, ...     3-5-2
# Nigeria         [V. Enyeama, C. Awaziem, K. Omeruo, U. Agbo, O...     3-5-2
# Senegal         [A. Gomis, K. Koulibaly, K. Mbodj, K. Mbodj, K...     3-5-2
# Tunisia         [F. Ben Mustapha, A. Abdennour, Y. Benalouane,...     3-5-2
# Australia       [M. Ryan, A. Gersbach, T. Sainsbury, B. Wright...     3-5-2
# Iran            [A. Haghighi, M. Mohammadi, K. Ansarifard, K. ...     3-5-2
# Japan           [K. Nakamura, G. Shoji, N. Ueda, M. Hasebe, Y....     3-5-2
# Korea Republic  [Yoon Bo Sang, Kim Min Jae, An Hyeon Beom, Kim...     3-5-2
# Saudi Arabia    [M. Al Owais, M. Hawsawi, O. Hawsawi, Y. Al Sh...     4-4-2
# Belgium         [T. Courtois, T. Alderweireld, L. Dendoncker, ...     3-5-2
# Croatia         [D. Subašić, T. Jedvaj, D. Lovren, S. Vrsaljko...     3-5-2
# Denmark         [K. Schmeichel, J. Vestergaard, S. Kjær, F. Sø...     3-5-2
# England         [J. Butland, M. Keane, A. Oxlade-Chamberlain, ...     3-5-2
# France          [A. Lafont, R. Varane, A. Laporte, S. Umtiti, ...     3-5-2
# Germany         [M. Neuer, N. Süle, J. Boateng, M. Hummels, J....     4-4-2
# Iceland         [R. Rúnarsson, S. Ingason, H. Hermannsson, D. ...     3-5-2
# Poland          [B. Drągowski, K. Glik, L. Piszczek, J. Bednar...     3-5-2
# Portugal        [A. Lopes, Nélson Semedo, Pepe, Rúben Semedo, ...     3-5-2
# Russia          [S. Kritsyuk, G. Dzhikiya, I. Kutepov, E. Nabi...     3-5-2
# Serbia          [F. Manojlović, M. Nastasić, N. Maksimović, V....     3-5-2
# Spain           [De Gea, Sergio Ramos, Héctor Bellerín, Piqué,...     3-5-2
# Sweden          [P. Dahlberg, V. Lindelöf, L. Augustinsson, A....     3-5-2
# Switzerland     [R. Bürki, R. Rodríguez, N. Elvedi, M. Akanji,...     3-5-2
# Costa Rica      [K. Navas, G. González, K. Waston, F. Calvo, C...     4-4-2
# Mexico          [G. Ochoa, D. Reyes, C. Montes, H. Moreno, J. ...     3-5-2
# Panama          [R. Torres, A. Machado, H. Cummings, F. Escoba...     3-5-2
# Argentina       [G. Rulli, M. Musacchio, E. Mammana, J. Foyth,...     3-5-2
# Brazil          [Ederson, Marquinhos, Thiago Silva, Marcelo, N...     3-5-2
# Colombia        [D. Ospina, D. Sánchez, J. Murillo, J. Lerma, ...     3-5-2
# Peru            [P. Gallese, C. Zambrano, A. Callens, A. Rodrí...     3-5-2
# Uruguay         [F. Muslera, D. Godín, J. Giménez, M. Saracchi...     3-5-2
#
#                 Tier  Rating  Attack  Midfield  Defence
# Country
# Egypt              2   79.00   82.33     83.00    74.17
# Morocco            2   81.55   84.00     82.50    78.83
# Nigeria            2   82.82   84.50     85.33    79.00
# Senegal            1   84.18   87.25     84.00    81.17
# Tunisia            3   74.45   78.00     76.00    72.33
# Australia          2   77.82   77.33     78.50    77.50
# Iran               3   76.55   79.75     79.00    71.67
# Japan              2   79.55   80.50     81.00    77.67
# Korea Republic     2   80.36   82.00     79.00    78.83
# Saudi Arabia       2   77.45   79.33     77.00    76.50
# Belgium            1   88.64   90.33     91.00    86.33
# Croatia            1   85.55   86.00     87.50    83.00
# Denmark            1   84.55   85.50     87.67    81.67
# England            1   87.64   90.00     89.00    85.50
# France             1   90.73   92.33     91.50    89.00
# Germany            1   88.82   88.00     89.67    88.50
# Iceland            3   75.82   75.50     77.67    74.67
# Poland             1   84.64   88.50     85.00    81.67
# Portugal           1   87.73   90.00     89.50    85.33
# Russia             2   81.82   82.00     83.33    80.50
# Serbia             2   83.45   85.50     84.00    82.00
# Spain              1   89.45   90.50     90.00    88.50
# Sweden             2   82.64   84.00     85.00    80.83
# Switzerland        1   84.45   85.67     85.50    83.33
# Costa Rica         3   75.91   80.00     75.75    75.17
# Mexico             2   82.45   85.00     83.75    80.33
# Panama             3   70.91   72.00     71.67    68.17
# Argentina          1   89.00   91.25     90.00    85.67
# Brazil             1   89.09   91.67     88.50    87.50
# Colombia           2   83.64   83.50     89.00    82.67
# Peru               3   76.91   77.50     78.33    74.83
# Uruguay            1   85.45   89.50     84.33    84.50

# %%
def get_country_squad(country):
    return fifa_dataset[fifa_dataset['Nationality'] == country]

#panama = get_country_squad('Panama')
#print panama
#print panama['Preferred Position']
#print iran['Preferred Position'].unique()
squad_list = [squad_352_strict, squad_442_strict, squad_433_strict, squad_343_strict, squad_532_strict]
squad_name = ['3-5-2', '4-4-2', '4-3-3', '3-4-3', '5-3-2']

#best_rating, best_squad, best_formation = get_best_formation_all(squad_list, 'Germany')
#print best_rating, best_squad, best_formation
#a,b = get_best_squad_n(squad_532_adj, 'Germany', fifa_dataset)
#print a,b
# for i, sq in enumerate(squad_list_adj):
#     print squad_name[i]
#     a,b = get_best_squad_n(sq, 'France', fifa_dataset)
#     print a, b

#print get_country_squad('France')

#rate, saudi, form, info = get_best_formation_all(squad_list_adj, 'Saudi Arabia')
#print saudi
#print rate, saudi, form, info
#
best_rating, best_squad, best_formation, squad_stats = get_best_formation_all(squad_list_adj, 'Senegal')
print get_team_stats(squad_stats)

#print info.split('\n')#[1:11]
# print team
# Out:
# Position Potential
# GK 81
# CB 87
# CB 80
# CB 80
# CB 80
# RB 79
# ST 90
# LW 87
# CAM 87
# ST 85
# CM 84
# (84.0, 81.170000000000002, 87.25)

# %%
# #print prior.head(5)
# #print fifa_dataset.tail(5)
# print 
# #print prior.shape
# saudi = fifa_dataset[fifa_dataset['Nationality'] == 'Saudi Arabia']
# print saudi

p=pd.DataFrame(d).reindex_axis(['Country', 'Squad', 'Formation', 'Tier', 'Rating', 'Attack', 'Midfield', 'Defence'], axis = 1).set_index('Country')
p.index.get_values()
# Out:
# array(['Egypt', 'Morocco', 'Nigeria', 'Senegal', 'Tunisia', 'Australia',
#        'Iran', 'Japan', 'Korea Republic', 'Saudi Arabia', 'Belgium',
#        'Croatia', 'Denmark', 'England', 'France', 'Germany', 'Iceland',
#        'Poland', 'Portugal', 'Russia', 'Serbia', 'Spain', 'Sweden',
#        'Switzerland', 'Costa Rica', 'Mexico', 'Panama', 'Argentina',
#        'Brazil', 'Colombia', 'Peru', 'Uruguay'], dtype=object)

# %%
#best_rating, best_squad, best_formation = get_best_formation_all(squad_list, 'Germany')
#print best_rating, best_squad, best_formation



#print best_squad
#get_team_stats(best_squad)
# --- 
#with open()


#------------

# def _pref(x):
#     prefs = temp.get_value(x,'Preferred Positions')
#     attr = []
#     if len(prefs)>1:
#         for i in prefs:
#              t = temp.get_value(x,i)
#              attr.append(t)
#         maxval = max(attr)
#         idx = attr.index(maxval)
#         return prefs[idx]
#     else:
#         return prefs[0]

# rating_352_EN_Overall, best_list_352_EN_Overall = get_best_squad_n(squad_352_strict, curCountry, fifa_dataset, 'Overall')
# rating_352_EN_Potential, best_list_352_EN_Potential = get_best_squad_n(squad_352_strict, curCountry, fifa_dataset,'Potential')

# # 
# print('-Overall-')
# print('Average rating: {:.1f}'.format(rating_352_EN_Overall))
# print(best_list_352_EN_Overall)

# print('-Potential-')
# print('Average rating: {:.1f}'.format(rating_352_EN_Potential))
# print(best_list_352_EN_Potential)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-210-d3c4fc38fe1d> in <module>()
#      13 for country in qualified_countries:
#      14         #print country
# ---> 15         best_rating, best_squad, best_formation = get_best_formation_all(squad_list_adj, country)
#      16         mid_rating, def_rating, att_rating = get_team_stats(best_squad)
#      17         if best_rating > 84.0: tier = 1
#
# ValueError: too many values to unpack

# %%
#np.histogram(scores,3)
#print scores
c=[]
for score in scores:
    if score < 77.: c.append(3)
    elif score < 84.: c.append(2)
    else: c.append(1)

#for s in list(zip(scores, c)): print s
print best_squad.split()
# Out:
# [u'Position', u'Player', u'Potential', u'GK', u'F.', u'Muslera', u'82', u'CB', u'D.', u'God\xedn', u'88', u'CB', u'J.', u'Gim\xe9nez', u'87', u'LWB', u'M.', u'Saracchi', u'85', u'ST', u'L.', u'Su\xe1rez', u'92', u'ST', u'E.', u'Cavani', u'87', u'CM', u'N.', u'N\xe1ndez', u'85', u'RM', u'F.', u'Valverde', u'85', u'CDM', u'M.', u'Lemos', u'83', u'CM', u'L.', u'Torreira', u'83', u'CM', u'R.', u'Bentancur', u'83']

# %%
#temp.set_index('Country')
temp = pd.DataFrame(d)
temp.set_index('Country')
# Out:
#                 Attack  Defence  Midfield  Overall Rating  \
# Country
# Egypt            82.33    75.50     81.00           79.00
# Morocco          83.25    79.50     82.50           81.55
# Nigeria          84.00    80.00     85.33           82.82
# Senegal          87.25    82.00     83.50           84.18
# Tunisia          78.00    72.50     75.25           74.45
# Australia        77.25    78.25     78.50           77.82
# Iran             79.75    74.50     76.50           76.55
# Japan            80.50    78.00     80.50           79.55
# Korea Republic   82.00    79.75     79.00           80.36
# Saudi Arabia     79.33    76.80     77.00           77.45
# Belgium          89.25    87.50     91.00           88.64
# Croatia          86.00    83.75     87.00           85.55
# Denmark          84.67    82.75     87.67           84.55
# England          90.00    86.00     88.60           87.64
# France           92.33    89.50     91.00           90.73
# Germany          88.00    89.00     89.67           88.82
# Iceland          75.00    75.50     77.67           75.82
# Poland           88.50    83.50     84.50           84.64
# Portugal         90.00    86.00     88.33           87.73
# Russia           81.67    81.00     83.33           81.82
# Serbia           85.50    82.25     83.75           83.45
# Spain            89.67    89.25     90.00           89.45
# Sweden           83.60    81.50     85.00           82.64
# Switzerland      85.67    84.25     84.33           84.45
# Costa Rica       80.00    75.80     75.75           75.91
# Mexico           83.50    80.75     83.75           82.45
# Panama           72.00    70.75     71.00           70.91
# Argentina        90.80    86.75     90.00           89.00
# Brazil           91.67    88.25     88.33           89.09
# Colombia         83.20    83.25     89.00           83.64
# Peru             77.50    76.25     77.75           76.91
# Uruguay          89.50    85.50     84.00           85.45
#
#                                                             Squad  Tier
# Country
# Egypt           Position         Player Potential\n     GK  A....     2
# Morocco         Position            Player Potential\n     GK ...     2
# Nigeria         Position        Player Potential\n     GK    V...     2
# Senegal         Position              Player Potential\n     G...     1
# Tunisia         Position           Player Potential\n     GK  ...     3
# Australia       Position        Player Potential\n     GK     ...     2
# Iran            Position             Player Potential\n     GK...     3
# Japan           Position        Player Potential\n     GK   K....     2
# Korea Republic  Position          Player Potential\n     GK   ...     2
# Saudi Arabia    Position          Player Potential\n     GK   ...     2
# Belgium         Position           Player Potential\n     GK  ...     1
# Croatia         Position        Player Potential\n     GK    D...     1
# Denmark         Position          Player Potential\n     GK   ...     1
# England         Position                 Player Potential\n   ...     1
# France          Position        Player Potential\n     GK     ...     1
# Germany         Position       Player Potential\n     GK     M...     1
# Iceland         Position           Player Potential\n     GK  ...     3
# Poland          Position          Player Potential\n     GK   ...     1
# Portugal        Position             Player Potential\n     GK...     1
# Russia          Position            Player Potential\n     GK ...     2
# Serbia          Position               Player Potential\n     ...     2
# Spain           Position           Player Potential\n     GK  ...     1
# Sweden          Position           Player Potential\n     GK  ...     2
# Switzerland     Position           Player Potential\n     GK  ...     1
# Costa Rica      Position        Player Potential\n     GK     ...     3
# Mexico          Position        Player Potential\n     GK     ...     2
# Panama          Position       Player Potential\n     GK    R....     3
# Argentina       Position        Player Potential\n     GK     ...     1
# Brazil          Position           Player Potential\n     GK  ...     1
# Colombia        Position        Player Potential\n     GK     ...     2
# Peru            Position        Player Potential\n     GK    P...     3
# Uruguay         Position        Player Potential\n     GK    F...     1

# %%
df.index
# Out:
# Index([u'Cristiano Ronaldo', u'L. Messi', u'Neymar', u'L. Suárez', u'M. Neuer',
#        u'R. Lewandowski', u'De Gea', u'E. Hazard', u'T. Kroos', u'G. Higuaín',
#        ...
#        u'R. White', u'A. Conway', u'T. Sawyer', u'J. Keeble', u'T. Käßemodel',
#        u'A. Kelsey', u'B. Richardson', u'J. Young', u'J. Lundstram',
#        u'L. Sackey'],
#       dtype='object', name=u'Name', length=17981)

# %%
# Egypt = fifa_dataset[fifa_dataset['Nationality']=='Egypt']
# Morocco = fifa_dataset[fifa_dataset['Nationality']=='Morocco']
# Nigeria = fifa_dataset[fifa_dataset['Nationality']=='Nigeria']
# Senegal = fifa_dataset[fifa_dataset['Nationality']=='Senegal']
# Tunisia = fifa_dataset[fifa_dataset['Nationality']=='Tunisia']
# Australia = fifa_dataset[fifa_dataset['Nationality']=='Australia']
# Iran = fifa_dataset[fifa_dataset['Nationality']=='Iran']
# Japan = fifa_dataset[fifa_dataset['Nationality']=='Japan']
# Korea = fifa_dataset[fifa_dataset['Nationality']=='Korea Republic']
# SaudiArabia = fifa_dataset[fifa_dataset['Nationality']=='Saudi Arabia']
# Belgium = fifa_dataset[fifa_dataset['Nationality']=='Belgium']
# Croatia = fifa_dataset[fifa_dataset['Nationality']=='Croatia']
# Denmark = fifa_dataset[fifa_dataset['Nationality']=='Denmark']
# England = fifa_dataset[fifa_dataset['Nationality']=='England']
# France = fifa_dataset[fifa_dataset['Nationality']=='France']
# Germany = fifa_dataset[fifa_dataset['Nationality']=='Germany']
# Iceland = fifa_dataset[fifa_dataset['Nationality']=='Iceland']
# Poland = fifa_dataset[fifa_dataset['Nationality']=='Poland']
# Portugal = fifa_dataset[fifa_dataset['Nationality']=='Russia']
# Serbia = fifa_dataset[fifa_dataset['Nationality']=='Serbia']
# Spain = fifa_dataset[fifa_dataset['Nationality']=='Spain']
# Switzerland = fifa_dataset[fifa_dataset['Nationality']=='Sweden']
# CostaRica = fifa_dataset[fifa_dataset['Nationality']=='Costa Rica']
# Mexico = fifa_dataset[fifa_dataset['Nationality']=='Mexico']
# Panema = fifa_dataset[fifa_dataset['Nationality']=='Panema']
# Argentina = fifa_dataset[fifa_dataset['Nationality']=='Argentina']
# Brazil = fifa_dataset[fifa_dataset['Nationality']=='Brazil']
# Colombia = fifa_dataset[fifa_dataset['Nationality']=='Colombia']
# Peru = fifa_dataset[fifa_dataset['Nationality']=='Peru']
# Uruguay = fifa_dataset[fifa_dataset['Nationality']=='Uruguay']
# Out:
#                    Age                                            Photo  \
# Name
# Cristiano Ronaldo   32   https://cdn.sofifa.org/48/18/players/20801.png
# L. Messi            30  https://cdn.sofifa.org/48/18/players/158023.png
# Neymar              25  https://cdn.sofifa.org/48/18/players/190871.png
# L. Suárez           30  https://cdn.sofifa.org/48/18/players/176580.png
# M. Neuer            31  https://cdn.sofifa.org/48/18/players/167495.png
# R. Lewandowski      28  https://cdn.sofifa.org/48/18/players/188545.png
# De Gea              26  https://cdn.sofifa.org/48/18/players/193080.png
# E. Hazard           26  https://cdn.sofifa.org/48/18/players/183277.png
# T. Kroos            27  https://cdn.sofifa.org/48/18/players/182521.png
# G. Higuaín          29  https://cdn.sofifa.org/48/18/players/167664.png
# Sergio Ramos        31  https://cdn.sofifa.org/48/18/players/155862.png
# K. De Bruyne        26  https://cdn.sofifa.org/48/18/players/192985.png
# T. Courtois         25  https://cdn.sofifa.org/48/18/players/192119.png
# A. Sánchez          28  https://cdn.sofifa.org/48/18/players/184941.png
# L. Modrić           31  https://cdn.sofifa.org/48/18/players/177003.png
# G. Bale             27  https://cdn.sofifa.org/48/18/players/173731.png
# S. Agüero           29  https://cdn.sofifa.org/48/18/players/153079.png
# G. Chiellini        32  https://cdn.sofifa.org/48/18/players/138956.png
# G. Buffon           39    https://cdn.sofifa.org/48/18/players/1179.png
# P. Dybala           23  https://cdn.sofifa.org/48/18/players/211110.png
# J. Oblak            24  https://cdn.sofifa.org/48/18/players/200389.png
# A. Griezmann        26  https://cdn.sofifa.org/48/18/players/194765.png
# Thiago              26  https://cdn.sofifa.org/48/18/players/189509.png
# P. Aubameyang       28  https://cdn.sofifa.org/48/18/players/188567.png
# L. Bonucci          30  https://cdn.sofifa.org/48/18/players/184344.png
# J. Boateng          28  https://cdn.sofifa.org/48/18/players/183907.png
# D. Godín            31  https://cdn.sofifa.org/48/18/players/182493.png
# M. Hummels          28  https://cdn.sofifa.org/48/18/players/178603.png
# M. Özil             28  https://cdn.sofifa.org/48/18/players/176635.png
# H. Lloris           30  https://cdn.sofifa.org/48/18/players/167948.png
# ...                ...                                              ...
# M. Hurst            21  https://cdn.sofifa.org/48/18/players/221669.png
# A. Osmanoski        17  https://cdn.sofifa.org/48/18/players/239079.png
# K. Cotter           18  https://cdn.sofifa.org/48/18/players/238833.png
# T. Robinson         19  https://cdn.sofifa.org/48/18/players/225778.png
# R. Hughes           18  https://cdn.sofifa.org/48/18/players/231928.png
# Z. Mohammed         17  https://cdn.sofifa.org/48/18/players/240381.png
# D. Peppard          17  https://cdn.sofifa.org/48/18/players/236807.png
# C. Rogers           17  https://cdn.sofifa.org/48/18/players/237859.png
# N. McLaughlin       18  https://cdn.sofifa.org/48/18/players/225319.png
# L. Kiely            18  https://cdn.sofifa.org/48/18/players/236597.png
# J. Latibeaudiere    17  https://cdn.sofifa.org/48/18/players/233047.png
# J. Payne            18  https://cdn.sofifa.org/48/18/players/236425.png
# G. Manley           19  https://cdn.sofifa.org/48/18/players/238217.png
# P. Phillips         18  https://cdn.sofifa.org/48/18/players/238985.png
# A. Byrne            18  https://cdn.sofifa.org/48/18/players/238219.png
# K. Fujikawa         18  https://cdn.sofifa.org/48/18/players/238477.png
# K. Egan             19  https://cdn.sofifa.org/48/18/players/231824.png
# T. Brownsword       17  https://cdn.sofifa.org/48/18/players/237974.png
# F. Prohart          18  https://cdn.sofifa.org/48/18/players/236954.png
# A. Kilgour          19  https://cdn.sofifa.org/48/18/players/231107.png
# R. White            18  https://cdn.sofifa.org/48/18/players/240325.png
# A. Conway           19  https://cdn.sofifa.org/48/18/players/238306.png
# T. Sawyer           18  https://cdn.sofifa.org/48/18/players/240403.png
# J. Keeble           18  https://cdn.sofifa.org/48/18/players/240404.png
# T. Käßemodel        28  https://cdn.sofifa.org/48/18/players/235352.png
# A. Kelsey           17  https://cdn.sofifa.org/48/18/players/237463.png
# B. Richardson       47   https://cdn.sofifa.org/48/18/players/11728.png
# J. Young            17  https://cdn.sofifa.org/48/18/players/231381.png
# J. Lundstram        18  https://cdn.sofifa.org/48/18/players/238813.png
# L. Sackey           18  https://cdn.sofifa.org/48/18/players/238308.png
#
#                            Nationality                                  Flag  \
# Name
# Cristiano Ronaldo             Portugal   https://cdn.sofifa.org/flags/38.png
# L. Messi                     Argentina   https://cdn.sofifa.org/flags/52.png
# Neymar                          Brazil   https://cdn.sofifa.org/flags/54.png
# L. Suárez                      Uruguay   https://cdn.sofifa.org/flags/60.png
# M. Neuer                       Germany   https://cdn.sofifa.org/flags/21.png
# R. Lewandowski                  Poland   https://cdn.sofifa.org/flags/37.png
# De Gea                           Spain   https://cdn.sofifa.org/flags/45.png
# E. Hazard                      Belgium    https://cdn.sofifa.org/flags/7.png
# T. Kroos                       Germany   https://cdn.sofifa.org/flags/21.png
# G. Higuaín                   Argentina   https://cdn.sofifa.org/flags/52.png
# Sergio Ramos                     Spain   https://cdn.sofifa.org/flags/45.png
# K. De Bruyne                   Belgium    https://cdn.sofifa.org/flags/7.png
# T. Courtois                    Belgium    https://cdn.sofifa.org/flags/7.png
# A. Sánchez                       Chile   https://cdn.sofifa.org/flags/55.png
# L. Modrić                      Croatia   https://cdn.sofifa.org/flags/10.png
# G. Bale                          Wales   https://cdn.sofifa.org/flags/50.png
# S. Agüero                    Argentina   https://cdn.sofifa.org/flags/52.png
# G. Chiellini                     Italy   https://cdn.sofifa.org/flags/27.png
# G. Buffon                        Italy   https://cdn.sofifa.org/flags/27.png
# P. Dybala                    Argentina   https://cdn.sofifa.org/flags/52.png
# J. Oblak                      Slovenia   https://cdn.sofifa.org/flags/44.png
# A. Griezmann                    France   https://cdn.sofifa.org/flags/18.png
# Thiago                           Spain   https://cdn.sofifa.org/flags/45.png
# P. Aubameyang                    Gabon  https://cdn.sofifa.org/flags/115.png
# L. Bonucci                       Italy   https://cdn.sofifa.org/flags/27.png
# J. Boateng                     Germany   https://cdn.sofifa.org/flags/21.png
# D. Godín                       Uruguay   https://cdn.sofifa.org/flags/60.png
# M. Hummels                     Germany   https://cdn.sofifa.org/flags/21.png
# M. Özil                        Germany   https://cdn.sofifa.org/flags/21.png
# H. Lloris                       France   https://cdn.sofifa.org/flags/18.png
# ...                                ...                                   ...
# M. Hurst                      Scotland   https://cdn.sofifa.org/flags/42.png
# A. Osmanoski             FYR Macedonia   https://cdn.sofifa.org/flags/19.png
# K. Cotter                      England   https://cdn.sofifa.org/flags/14.png
# T. Robinson                    England   https://cdn.sofifa.org/flags/14.png
# R. Hughes                     Scotland   https://cdn.sofifa.org/flags/42.png
# Z. Mohammed                    England   https://cdn.sofifa.org/flags/14.png
# D. Peppard         Republic of Ireland   https://cdn.sofifa.org/flags/25.png
# C. Rogers          Republic of Ireland   https://cdn.sofifa.org/flags/25.png
# N. McLaughlin                 Scotland   https://cdn.sofifa.org/flags/42.png
# L. Kiely           Republic of Ireland   https://cdn.sofifa.org/flags/25.png
# J. Latibeaudiere               England   https://cdn.sofifa.org/flags/14.png
# J. Payne                       England   https://cdn.sofifa.org/flags/14.png
# G. Manley          Republic of Ireland   https://cdn.sofifa.org/flags/25.png
# P. Phillips        Republic of Ireland   https://cdn.sofifa.org/flags/25.png
# A. Byrne           Republic of Ireland   https://cdn.sofifa.org/flags/25.png
# K. Fujikawa                      Japan  https://cdn.sofifa.org/flags/163.png
# K. Egan                        England   https://cdn.sofifa.org/flags/14.png
# T. Brownsword                  England   https://cdn.sofifa.org/flags/14.png
# F. Prohart                     Austria    https://cdn.sofifa.org/flags/4.png
# A. Kilgour                     England   https://cdn.sofifa.org/flags/14.png
# R. White                       England   https://cdn.sofifa.org/flags/14.png
# A. Conway          Republic of Ireland   https://cdn.sofifa.org/flags/25.png
# T. Sawyer                      England   https://cdn.sofifa.org/flags/14.png
# J. Keeble                      England   https://cdn.sofifa.org/flags/14.png
# T. Käßemodel                   Germany   https://cdn.sofifa.org/flags/21.png
# A. Kelsey                      England   https://cdn.sofifa.org/flags/14.png
# B. Richardson                  England   https://cdn.sofifa.org/flags/14.png
# J. Young                      Scotland   https://cdn.sofifa.org/flags/42.png
# J. Lundstram                   England   https://cdn.sofifa.org/flags/14.png
# L. Sackey                        Ghana  https://cdn.sofifa.org/flags/117.png
#
#                    Overall  Potential                    Club  \
# Name
# Cristiano Ronaldo       94         94          Real Madrid CF
# L. Messi                93         93            FC Barcelona
# Neymar                  92         94     Paris Saint-Germain
# L. Suárez               92         92            FC Barcelona
# M. Neuer                92         92        FC Bayern Munich
# R. Lewandowski          91         91        FC Bayern Munich
# De Gea                  90         92       Manchester United
# E. Hazard               90         91                 Chelsea
# T. Kroos                90         90          Real Madrid CF
# G. Higuaín              90         90                Juventus
# Sergio Ramos            90         90          Real Madrid CF
# K. De Bruyne            89         92         Manchester City
# T. Courtois             89         92                 Chelsea
# A. Sánchez              89         89                 Arsenal
# L. Modrić               89         89          Real Madrid CF
# G. Bale                 89         89          Real Madrid CF
# S. Agüero               89         89         Manchester City
# G. Chiellini            89         89                Juventus
# G. Buffon               89         89                Juventus
# P. Dybala               88         93                Juventus
# J. Oblak                88         93         Atlético Madrid
# A. Griezmann            88         91         Atlético Madrid
# Thiago                  88         90        FC Bayern Munich
# P. Aubameyang           88         88       Borussia Dortmund
# L. Bonucci              88         88                   Milan
# J. Boateng              88         88        FC Bayern Munich
# D. Godín                88         88         Atlético Madrid
# M. Hummels              88         88        FC Bayern Munich
# M. Özil                 88         88                 Arsenal
# H. Lloris               88         88       Tottenham Hotspur
# ...                    ...        ...                     ...
# M. Hurst                48         58        St. Johnstone FC
# A. Osmanoski            48         68      SpVgg Unterhaching
# K. Cotter               48         67              Luton Town
# T. Robinson             48         64           Bradford City
# R. Hughes               48         63  Hamilton Academical FC
# Z. Mohammed             48         64      Accrington Stanley
# D. Peppard              47         61             Bohemian FC
# C. Rogers               47         59          Bray Wanderers
# N. McLaughlin           47         64    Partick Thistle F.C.
# L. Kiely                47         69         Shamrock Rovers
# J. Latibeaudiere        47         73         Manchester City
# J. Payne                47         63                  Barnet
# G. Manley               47         58               Cork City
# P. Phillips             47         67               Cork City
# A. Byrne                47         61               Cork City
# K. Fujikawa             47         67            Júbilo Iwata
# K. Egan                 47         67             Exeter City
# T. Brownsword           47         68               Morecambe
# F. Prohart              47         67          Wolfsberger AC
# A. Kilgour              47         56          Bristol Rovers
# R. White                47         65        Bolton Wanderers
# A. Conway               47         63           Galway United
# T. Sawyer               46         58            Grimsby Town
# J. Keeble               46         56            Grimsby Town
# T. Käßemodel            46         46       FC Erzgebirge Aue
# A. Kelsey               46         63       Scunthorpe United
# B. Richardson           46         46       Wycombe Wanderers
# J. Young                46         61            Swindon Town
# J. Lundstram            46         64         Crewe Alexandra
# L. Sackey               46         64       Scunthorpe United
#
#                                                        Club Logo   Value  \
# Name
# Cristiano Ronaldo     https://cdn.sofifa.org/24/18/teams/243.png  €95.5M
# L. Messi              https://cdn.sofifa.org/24/18/teams/241.png   €105M
# Neymar                 https://cdn.sofifa.org/24/18/teams/73.png   €123M
# L. Suárez             https://cdn.sofifa.org/24/18/teams/241.png    €97M
# M. Neuer               https://cdn.sofifa.org/24/18/teams/21.png    €61M
# R. Lewandowski         https://cdn.sofifa.org/24/18/teams/21.png    €92M
# De Gea                 https://cdn.sofifa.org/24/18/teams/11.png  €64.5M
# E. Hazard               https://cdn.sofifa.org/24/18/teams/5.png  €90.5M
# T. Kroos              https://cdn.sofifa.org/24/18/teams/243.png    €79M
# G. Higuaín             https://cdn.sofifa.org/24/18/teams/45.png    €77M
# Sergio Ramos          https://cdn.sofifa.org/24/18/teams/243.png    €52M
# K. De Bruyne           https://cdn.sofifa.org/24/18/teams/10.png    €83M
# T. Courtois             https://cdn.sofifa.org/24/18/teams/5.png    €59M
# A. Sánchez              https://cdn.sofifa.org/24/18/teams/1.png  €67.5M
# L. Modrić             https://cdn.sofifa.org/24/18/teams/243.png    €57M
# G. Bale               https://cdn.sofifa.org/24/18/teams/243.png  €69.5M
# S. Agüero              https://cdn.sofifa.org/24/18/teams/10.png  €66.5M
# G. Chiellini           https://cdn.sofifa.org/24/18/teams/45.png    €38M
# G. Buffon              https://cdn.sofifa.org/24/18/teams/45.png   €4.5M
# P. Dybala              https://cdn.sofifa.org/24/18/teams/45.png    €79M
# J. Oblak              https://cdn.sofifa.org/24/18/teams/240.png    €57M
# A. Griezmann          https://cdn.sofifa.org/24/18/teams/240.png    €75M
# Thiago                 https://cdn.sofifa.org/24/18/teams/21.png  €70.5M
# P. Aubameyang          https://cdn.sofifa.org/24/18/teams/22.png    €61M
# L. Bonucci             https://cdn.sofifa.org/24/18/teams/47.png    €44M
# J. Boateng             https://cdn.sofifa.org/24/18/teams/21.png    €48M
# D. Godín              https://cdn.sofifa.org/24/18/teams/240.png    €40M
# M. Hummels             https://cdn.sofifa.org/24/18/teams/21.png    €48M
# M. Özil                 https://cdn.sofifa.org/24/18/teams/1.png    €60M
# H. Lloris              https://cdn.sofifa.org/24/18/teams/18.png    €38M
# ...                                                          ...     ...
# M. Hurst           https://cdn.sofifa.org/24/18/teams/100804.png    €40K
# A. Osmanoski          https://cdn.sofifa.org/24/18/teams/172.png    €60K
# K. Cotter            https://cdn.sofifa.org/24/18/teams/1923.png    €60K
# T. Robinson          https://cdn.sofifa.org/24/18/teams/1804.png    €60K
# R. Hughes             https://cdn.sofifa.org/24/18/teams/184.png    €60K
# Z. Mohammed        https://cdn.sofifa.org/24/18/teams/110313.png    €50K
# D. Peppard            https://cdn.sofifa.org/24/18/teams/305.png    €50K
# C. Rogers             https://cdn.sofifa.org/24/18/teams/838.png    €40K
# N. McLaughlin        https://cdn.sofifa.org/24/18/teams/1754.png    €60K
# L. Kiely              https://cdn.sofifa.org/24/18/teams/306.png    €70K
# J. Latibeaudiere       https://cdn.sofifa.org/24/18/teams/10.png    €60K
# J. Payne              https://cdn.sofifa.org/24/18/teams/135.png    €50K
# G. Manley             https://cdn.sofifa.org/24/18/teams/422.png    €50K
# P. Phillips           https://cdn.sofifa.org/24/18/teams/422.png    €60K
# A. Byrne              https://cdn.sofifa.org/24/18/teams/422.png    €60K
# K. Fujikawa        https://cdn.sofifa.org/24/18/teams/101144.png    €60K
# K. Egan               https://cdn.sofifa.org/24/18/teams/143.png    €60K
# T. Brownsword         https://cdn.sofifa.org/24/18/teams/357.png    €60K
# F. Prohart         https://cdn.sofifa.org/24/18/teams/111822.png    €60K
# A. Kilgour           https://cdn.sofifa.org/24/18/teams/1962.png    €40K
# R. White                https://cdn.sofifa.org/24/18/teams/4.png    €60K
# A. Conway            https://cdn.sofifa.org/24/18/teams/1571.png    €60K
# T. Sawyer              https://cdn.sofifa.org/24/18/teams/92.png    €50K
# J. Keeble              https://cdn.sofifa.org/24/18/teams/92.png    €40K
# T. Käßemodel          https://cdn.sofifa.org/24/18/teams/506.png    €30K
# A. Kelsey            https://cdn.sofifa.org/24/18/teams/1949.png    €50K
# B. Richardson        https://cdn.sofifa.org/24/18/teams/1933.png      €0
# J. Young             https://cdn.sofifa.org/24/18/teams/1934.png    €60K
# J. Lundstram          https://cdn.sofifa.org/24/18/teams/121.png    €60K
# L. Sackey            https://cdn.sofifa.org/24/18/teams/1949.png    €50K
#
#                     Wage  ...     RB   RCB   RCM   RDM    RF    RM    RS  \
# Name                      ...
# Cristiano Ronaldo  €565K  ...   61.0  53.0  82.0  62.0  91.0  89.0  92.0
# L. Messi           €565K  ...   57.0  45.0  84.0  59.0  92.0  90.0  88.0
# Neymar             €280K  ...   59.0  46.0  79.0  59.0  88.0  87.0  84.0
# L. Suárez          €510K  ...   64.0  58.0  80.0  65.0  88.0  85.0  88.0
# M. Neuer           €230K  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# R. Lewandowski     €355K  ...   58.0  57.0  78.0  62.0  87.0  82.0  88.0
# De Gea             €215K  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# E. Hazard          €295K  ...   59.0  47.0  81.0  61.0  87.0  87.0  82.0
# T. Kroos           €340K  ...   76.0  72.0  87.0  82.0  81.0  81.0  77.0
# G. Higuaín         €275K  ...   51.0  46.0  71.0  52.0  84.0  79.0  87.0
# Sergio Ramos       €310K  ...   84.0  87.0  74.0  83.0  70.0  71.0  72.0
# K. De Bruyne       €285K  ...   66.0  57.0  84.0  70.0  85.0  85.0  81.0
# T. Courtois        €190K  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# A. Sánchez         €265K  ...   62.0  56.0  79.0  64.0  85.0  85.0  83.0
# L. Modrić          €340K  ...   78.0  72.0  86.0  80.0  83.0  84.0  76.0
# G. Bale            €370K  ...   72.0  67.0  81.0  71.0  87.0  87.0  87.0
# S. Agüero          €325K  ...   52.0  44.0  75.0  54.0  87.0  84.0  86.0
# G. Chiellini       €225K  ...   78.0  86.0  60.0  76.0  55.0  58.0  59.0
# G. Buffon          €110K  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# P. Dybala          €215K  ...   55.0  43.0  78.0  55.0  86.0  86.0  83.0
# J. Oblak            €82K  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# A. Griezmann       €150K  ...   56.0  48.0  76.0  57.0  85.0  84.0  85.0
# Thiago             €225K  ...   72.0  66.0  85.0  76.0  83.0  83.0  77.0
# P. Aubameyang      €165K  ...   62.0  52.0  74.0  59.0  84.0  83.0  85.0
# L. Bonucci         €210K  ...   79.0  86.0  75.0  83.0  66.0  66.0  65.0
# J. Boateng         €215K  ...   81.0  85.0  73.0  82.0  66.0  69.0  65.0
# D. Godín           €125K  ...   79.0  86.0  69.0  80.0  62.0  63.0  64.0
# M. Hummels         €215K  ...   80.0  85.0  77.0  83.0  69.0  70.0  69.0
# M. Özil            €265K  ...   52.0  41.0  79.0  57.0  82.0  83.0  76.0
# H. Lloris          €165K  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# ...                  ...  ...    ...   ...   ...   ...   ...   ...   ...
# M. Hurst             €1K  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# A. Osmanoski         €1K  ...   47.0  46.0  47.0  47.0  47.0  48.0  46.0
# K. Cotter            €1K  ...   47.0  44.0  47.0  46.0  45.0  48.0  44.0
# T. Robinson          €1K  ...   37.0  32.0  41.0  35.0  45.0  47.0  45.0
# R. Hughes            €1K  ...   47.0  48.0  47.0  48.0  46.0  47.0  44.0
# Z. Mohammed          €1K  ...   44.0  47.0  33.0  41.0  32.0  34.0  34.0
# D. Peppard           €1K  ...   46.0  45.0  41.0  45.0  39.0  42.0  37.0
# C. Rogers            €1K  ...   46.0  47.0  36.0  43.0  35.0  37.0  37.0
# N. McLaughlin        €1K  ...   43.0  40.0  46.0  44.0  47.0  48.0  46.0
# L. Kiely             €1K  ...   41.0  41.0  45.0  43.0  44.0  45.0  42.0
# J. Latibeaudiere     €5K  ...   45.0  46.0  35.0  42.0  32.0  35.0  32.0
# J. Payne             €1K  ...   46.0  46.0  35.0  40.0  36.0  39.0  36.0
# G. Manley            €1K  ...   46.0  48.0  46.0  48.0  42.0  44.0  41.0
# P. Phillips          €1K  ...   47.0  48.0  46.0  48.0  43.0  44.0  41.0
# A. Byrne             €1K  ...   46.0  43.0  46.0  46.0  46.0  47.0  44.0
# K. Fujikawa          €1K  ...   46.0  47.0  46.0  47.0  43.0  45.0  40.0
# K. Egan              €1K  ...   46.0  46.0  37.0  41.0  38.0  42.0  37.0
# T. Brownsword        €1K  ...   45.0  46.0  32.0  40.0  32.0  34.0  33.0
# F. Prohart           €1K  ...   33.0  27.0  41.0  31.0  48.0  47.0  46.0
# A. Kilgour           €1K  ...   43.0  46.0  38.0  43.0  37.0  38.0  38.0
# R. White             €2K  ...   33.0  32.0  42.0  33.0  49.0  46.0  52.0
# A. Conway            €1K  ...   46.0  45.0  41.0  43.0  42.0  44.0  42.0
# T. Sawyer            €1K  ...   45.0  42.0  45.0  43.0  46.0  47.0  45.0
# J. Keeble            €1K  ...   46.0  45.0  34.0  41.0  33.0  35.0  33.0
# T. Käßemodel         €1K  ...   37.0  38.0  45.0  42.0  42.0  42.0  41.0
# A. Kelsey            €1K  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# B. Richardson        €1K  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN
# J. Young             €1K  ...   31.0  28.0  38.0  29.0  45.0  42.0  45.0
# J. Lundstram         €1K  ...   47.0  46.0  45.0  47.0  43.0  45.0  41.0
# L. Sackey            €1K  ...   40.0  45.0  30.0  38.0  29.0  30.0  31.0
#
#                      RW   RWB    ST
# Name
# Cristiano Ronaldo  91.0  66.0  92.0
# L. Messi           91.0  62.0  88.0
# Neymar             89.0  64.0  84.0
# L. Suárez          87.0  68.0  88.0
# M. Neuer            NaN   NaN   NaN
# R. Lewandowski     84.0  61.0  88.0
# De Gea              NaN   NaN   NaN
# E. Hazard          88.0  64.0  82.0
# T. Kroos           80.0  78.0  77.0
# G. Higuaín         82.0  55.0  87.0
# Sergio Ramos       69.0  81.0  72.0
# K. De Bruyne       85.0  71.0  81.0
# T. Courtois         NaN   NaN   NaN
# A. Sánchez         86.0  66.0  83.0
# L. Modrić          83.0  80.0  76.0
# G. Bale            87.0  74.0  87.0
# S. Agüero          86.0  57.0  86.0
# G. Chiellini       56.0  75.0  59.0
# G. Buffon           NaN   NaN   NaN
# P. Dybala          87.0  60.0  83.0
# J. Oblak            NaN   NaN   NaN
# A. Griezmann       86.0  60.0  85.0
# Thiago             83.0  75.0  77.0
# P. Aubameyang      84.0  65.0  85.0
# L. Bonucci         63.0  76.0  65.0
# J. Boateng         65.0  79.0  65.0
# D. Godín           61.0  76.0  64.0
# M. Hummels         68.0  78.0  69.0
# M. Özil            83.0  58.0  76.0
# H. Lloris           NaN   NaN   NaN
# ...                 ...   ...   ...
# M. Hurst            NaN   NaN   NaN
# A. Osmanoski       47.0  47.0  46.0
# K. Cotter          46.0  48.0  44.0
# T. Robinson        47.0  39.0  45.0
# R. Hughes          46.0  47.0  44.0
# Z. Mohammed        33.0  42.0  34.0
# D. Peppard         40.0  46.0  37.0
# C. Rogers          35.0  44.0  37.0
# N. McLaughlin      47.0  44.0  46.0
# L. Kiely           44.0  41.0  42.0
# J. Latibeaudiere   32.0  43.0  32.0
# J. Payne           38.0  45.0  36.0
# G. Manley          42.0  46.0  41.0
# P. Phillips        42.0  46.0  41.0
# A. Byrne           45.0  46.0  44.0
# K. Fujikawa        44.0  46.0  40.0
# K. Egan            42.0  46.0  37.0
# T. Brownsword      32.0  43.0  33.0
# F. Prohart         49.0  35.0  46.0
# A. Kilgour         37.0  42.0  38.0
# R. White           47.0  34.0  52.0
# A. Conway          44.0  46.0  42.0
# T. Sawyer          47.0  46.0  45.0
# J. Keeble          34.0  44.0  33.0
# T. Käßemodel       41.0  38.0  41.0
# A. Kelsey           NaN   NaN   NaN
# B. Richardson       NaN   NaN   NaN
# J. Young           44.0  32.0  45.0
# J. Lundstram       44.0  46.0  41.0
# L. Sackey          29.0  38.0  31.0
#
# [17981 rows x 73 columns]
